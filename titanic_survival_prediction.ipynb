# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# загружаем данные
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# оставляем нужные колонки
df = df[['Survived', 'Pclass', 'Age', 'Fare']]

# удаляем пустые значения
df = df.dropna()

# разделяем данные
X = df[['Pclass', 'Age', 'Fare']]
y = df['Survived']

# делим на train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# модель
model = LogisticRegression()
model.fit(X_train, y_train)

# точность
accuracy = model.score(X_test, y_test)
print("Model accuracy:", accuracy)
# Out:
# Model accuracy: 0.7062937062937062

# %% [markdown]
# ## Conclusion
#
# The model predicts survival on the Titanic with reasonable accuracy.
# Factors such as passenger class, age, and fare influence survival chances.
